# %% [markdown]
# <a href="https://colab.research.google.com/github/Girishhuber/Ml/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv("heart_v2.csv")
df
# Out:
#      age  sex   BP  cholestrol  heart disease
# 0     70    1  130         322              1
# 1     67    0  115         564              0
# 2     57    1  124         261              1
# 3     64    1  128         263              0
# 4     74    0  120         269              0
# ..   ...  ...  ...         ...            ...
# 265   52    1  172         199              0
# 266   44    1  120         263              0
# 267   56    0  140         294              0
# 268   57    1  140         192              0
# 269   67    1  160         286              1
#
# [270 rows x 5 columns]

# %%
x = df.drop("heart disease",axis=1)
x
# Out:
#      age  sex   BP  cholestrol
# 0     70    1  130         322
# 1     67    0  115         564
# 2     57    1  124         261
# 3     64    1  128         263
# 4     74    0  120         269
# ..   ...  ...  ...         ...
# 265   52    1  172         199
# 266   44    1  120         263
# 267   56    0  140         294
# 268   57    1  140         192
# 269   67    1  160         286
#
# [270 rows x 4 columns]

# %%
y = df["heart disease"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: heart disease, Length: 270, dtype: int64

# %%
from sklearn.model_selection import train_test_split 
train_X, test_X, train_y, test_y = train_test_split(x,y, train_size=0.5, test_size=0.5, random_state=0)
test_X
# Out:
#      age  sex   BP  cholestrol
# 64    63    1  145         233
# 135   46    0  142         177
# 153   64    0  130         303
# 189   70    1  160         269
# 253   51    1  110         175
# ..   ...  ...  ...         ...
# 228   58    0  150         283
# 104   63    1  130         254
# 173   68    0  120         211
# 86    62    1  128         208
# 10    59    1  135         234
#
# [135 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()
ml.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
y_pred = ml.predict( test_X)
print(y_pred )
# Out:
# [ 0.73542949  0.06301972  0.38025691  0.86283642  0.51396546  0.42846944
#   0.65147571  0.41794464  0.71342835  0.4007313   0.19722643  0.62844633
#   0.61205198  0.6843097   0.71723364  0.14149725  0.64913995  0.96387863
#   0.73052149  0.49552162  0.58766269 -0.01950751  0.66150446  0.43850606
#   0.46676402  0.39616911  0.60374221  0.42333332  0.39914684  0.7830129
#   0.7990895   0.37397822  0.67091621 -0.0037244   0.09141241  0.33202345
#   0.60822411  0.39896734  0.43780633  0.36595213  0.4808383   0.18072247
#   0.1674592   0.3459375   0.19051787  0.70347366  0.55501529  0.60561054
#   0.77923     0.84623853  0.31517591  0.64472866  0.31421251  0.55566805
#   0.72532219  0.45980528  0.2507575   0.28556221  0.45525602  0.68345717
#   0.30218541  0.51907501  0.66852805  0.39574248  0.51122552  0.65985974
#   0.81555121  0.83072726  0.60095273  0.20096529  0.53101163  0.72156168
#   0.63002223  0.49793548  0.55217414  0.29657822  0.64772209  0.61932575
# ...

# %%
from sklearn.metrics import r2_score
r2_score(test_y,y_pred)
# Out:
# 0.09981714283497256

# %%
plt.scatter(test_y,y_pred)
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.title('Actual vs predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs predicted')
